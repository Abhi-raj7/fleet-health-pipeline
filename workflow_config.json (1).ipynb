# %%
{
  "name": "fleet_pipeline",
  "tasks": [
    {
      "task_key": "bronze_ingestion",
      "notebook_task": {
        "notebook_path": "/Workspace/Users/iamabhishekkb@gmail.com/01_bronze"
      },
      "depends_on": []
    },
    {
      "task_key": "silver_transform",
      "notebook_task": {
        "notebook_path": "/Workspace/Users/iamabhishekkb@gmail.com/02_Silver_transformation"
      },
      "depends_on": [{"task_key": "bronze_ingestion"}]
    },
    {
      "task_key": "gold_analytics",
      "notebook_task": {
        "notebook_path": "/Workspace/Users/iamabhishekkb@gmail.com/03_gold_analytics"
      },
      "depends_on": [{"task_key": "silver_transform"}]
    }
  ]
}
